# %%
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
img_path='Image1.png'

# %%
reader=easyocr.Reader(['en'])
result=reader.readtext(img_path)
print(result)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[148, 138], [629, 138], [629, 192], [148, 192]], 'To all our readers in India;', 0.6691394455762386), ([[99, 225], [1497, 225], [1497, 291], [99, 291]], "Please don't scroll past this. This Saturday; we kindly request your support.", 0.7305165874645124), ([[98, 297], [1657, 297], [1657, 360], [98, 360]], 'Wikipedia relies on donations and participation, yet only 2% of readers ever donate.', 0.6286055507956255), ([[99, 363], [1657, 363], [1657, 428], [99, 428]], 'If you are an exceptional reader who has already donated, we sincerely thank you: If', 0.5792448516409644), ([[97, 434], [1591, 434], [1591, 497], [97, 497]], 'you donate just ? 50 today; Wikipedia could keep growing for years: We request', 0.41997841417582976), ([[97, 502], [1633, 502], [1633, 567], [97, 567]], "you: please don't scroll away: If Wikipedia has given you ? 50 worth of knowledge;", 0.5127083899232582), ([[95, 571], [1543, 571], [1543, 635], [95, 635]], 'kindly take a minute to donate. Show the world that access to reliable, neutral', 0.750756324399669), ([[98, 646], [824, 646], [824, 700], [98, 700]], 'information matters to you: Thank you:', 0.9012479868955349)]

# %%
img=cv2.imread(img_path)
for detection in result:
    top_left=tuple(int(val) for val in detection[0][0])
    bottom_right=tuple(int(val) for val in detection[0][2])
    text=detection[1]
    font=cv2.FONT_HERSHEY_SIMPLEX
    img=cv2.rectangle(img,top_left,bottom_right,(0,255,0),5)
    img=cv2.putText(img,text,top_left,font,1.2,(0,0,0),2,cv2.LINE_AA)
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()

# %%
for detection in result:
    print(detection[1])
# Out:
# To all our readers in India;
# Please don't scroll past this. This Saturday; we kindly request your support.
# Wikipedia relies on donations and participation, yet only 2% of readers ever donate.
# If you are an exceptional reader who has already donated, we sincerely thank you: If
# you donate just ? 50 today; Wikipedia could keep growing for years: We request
# you: please don't scroll away: If Wikipedia has given you ? 50 worth of knowledge;
# kindly take a minute to donate. Show the world that access to reliable, neutral
# information matters to you: Thank you:
